# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import scipy.stats as st

# %%
df = pd.read_csv("../bcancer.csv")
df.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
df.isnull().sum()
# Out:
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64

# %%
df.diagnosis.value_counts()
# Out:
# diagnosis
# B    357
# M    212
# Name: count, dtype: int64

# %%
class_p = df.diagnosis.value_counts(normalize=True)
class_p
# Out:
# diagnosis
# B    0.627417
# M    0.372583
# Name: proportion, dtype: float64

# %%
p_m = class_p['M']
p_b = class_p["B"]
p_m, p_b
# Out:
# (0.37258347978910367, 0.6274165202108963)

# %%
data1 = df[['diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean']]
data1.head(2)
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean
# 0         M        17.99         10.38           122.8     1001.0
# 1         M        20.57         17.77           132.9     1326.0

# %%
data_m = data1[data1.diagnosis == "M"]
data_b = data1[data1.diagnosis == "B"]

# %%
test = np.array([17.99, 10.38, 122.8, 1001.0])
test
# Out:
# array([  17.99,   10.38,  122.8 , 1001.  ])

# %%
prob_m = st.gaussian_kde(data_m["radius_mean"]).pdf(test[0]) * st.gaussian_kde(data_m["texture_mean"]).pdf(test[1]) * st.gaussian_kde(data_m["perimeter_mean"]).pdf(test[2]) *  st.gaussian_kde(data_m["area_mean"]).pdf(test[3]) * p_m
prob_m
# Out:
# array([1.29869883e-09])

# %%
prob_b = st.gaussian_kde(data_b["radius_mean"]).pdf(test[0]) * st.gaussian_kde(data_b["texture_mean"]).pdf(test[1]) * st.gaussian_kde(data_b["perimeter_mean"]).pdf(test[2]) *  st.gaussian_kde(data_b["area_mean"]).pdf(test[3]) * p_b
prob_b
# Out:
# array([1.00561393e-14])

# %%
if prob_m > prob_b:
    print("The test data belongs to maligant")
else:
    print("the test data belongs to benign")
# Out:
# The test data belongs to maligant

# %%
from sklearn.naive_bayes import GaussianNB, MultinomialNB, BernoulliNB

# %%
inp = df.drop(columns="diagnosis")
out = df.diagnosis

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(inp, out, test_size=0.3, random_state=48)

# %%
gnb = GaussianNB()
gnb.fit(xtrain, ytrain)
# Out:
# GaussianNB()

# %%
pred = gnb.predict(xtest)
pred
# Out:
# array(['B', 'M', 'M', 'M', 'B', 'M', 'B', 'M', 'M', 'M', 'B', 'B', 'M',
#        'B', 'M', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'B',
#        'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'M',
#        'M', 'M', 'M', 'B', 'B', 'M', 'M', 'M', 'M', 'B', 'M', 'B', 'B',
#        'M', 'B', 'M', 'B', 'M', 'B', 'B', 'M', 'M', 'B', 'M', 'B', 'B',
#        'B', 'B', 'M', 'M', 'B', 'M', 'B', 'B', 'B', 'B', 'M', 'M', 'B',
#        'M', 'M', 'M', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'M', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'M', 'M',
#        'M', 'M', 'B', 'B', 'M', 'M', 'M', 'B', 'M', 'B', 'B', 'B', 'M',
#        'M', 'M', 'M', 'M', 'M', 'B', 'M', 'M', 'M', 'B', 'M', 'M', 'M',
#        'M', 'B', 'M', 'M', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'M', 'B',
#        'B', 'M', 'B', 'M', 'B', 'B', 'M', 'B', 'M', 'M', 'B', 'B', 'B',
#        'B', 'M'], dtype='<U1')

# %%
# All input follow normal distrubution the use GaussianNB
# All input are boolean in nature then use BernoulliNB
# All input varibale are having frequency count the use MultinomialNB
